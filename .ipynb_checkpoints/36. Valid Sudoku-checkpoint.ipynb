# %% [markdown]
# Determine if a 9 x 9 Sudoku board is valid. Only the filled cells need to be validated according to the following rules:
#
# Each row must contain the digits 1-9 without repetition.
# Each column must contain the digits 1-9 without repetition.
# Each of the nine 3 x 3 sub-boxes of the grid must contain the digits 1-9 without repetition.
# Note:
# A Sudoku board (partially filled) could be valid but is not necessarily solvable.
# Only the filled cells need to be validated according to the mentioned rules.
#
#
# Example 1:
#
# Input:
#
# board =
#
# [["5","3",".",".","7",".",".",".","."]
#
# ,["6",".",".","1","9","5",".",".","."]
#
# ,[".","9","8",".",".",".",".","6","."]
#
# ,["8",".",".",".","6",".",".",".","3"]
#
# ,["4",".",".","8",".","3",".",".","1"]
#
# ,["7",".",".",".","2",".",".",".","6"]
#
# ,[".","6",".",".",".",".","2","8","."]
#
# ,[".",".",".","4","1","9",".",".","5"]
#
# ,[".",".",".",".","8",".",".","7","9"]]
#
# Output: true
#
# Example 2:
#
# Input:
#
# board =
#
# [["8","3",".",".","7",".",".",".","."]
#
# ,["6",".",".","1","9","5",".",".","."]
#
# ,[".","9","8",".",".",".",".","6","."]
#
# ,["8",".",".",".","6",".",".",".","3"]
#
# ,["4",".",".","8",".","3",".",".","1"]
#
# ,["7",".",".",".","2",".",".",".","6"]
#
# ,[".","6",".",".",".",".","2","8","."]
#
# ,[".",".",".","4","1","9",".",".","5"]
#
# ,[".",".",".",".","8",".",".","7","9"]]
#
# Output: false
# Explanation: Same as Example 1, except with the 5 in the top left corner being modified to 8. Since there are two 8's in the top left 3x3 sub-box, it is invalid.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def isValidSudoku(board):
    dict1={}
    for i in range(9): #橫
        for j in range(9): #直
            if board[i][j]!='.':
                d=int(board[i][j])
                if (i,-1,d) in dict1 or (-1,j,d) in dict1 or (i//3,j//3,d) in dict1: #橫,直,3X3方格
                    return False
                dict1[(i,-1,d)]=True #新增值
                dict1[(-1,j,d)]=True
                dict1[(i//3,j//3,d)]=True 
                print(dict1)
                print("---")
    return True

# %%
isValidSudoku([["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]])
# Out:
# True

# %%
isValidSudoku([["8","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]])
# Out:
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True, (1, -1, 6): True, (-1, 0, 6): True, (0, 0, 6): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True, (1, -1, 6): True, (-1, 0, 6): True, (0, 0, 6): True, (1, -1, 1): True, (-1, 3, 1): True, (0, 1, 1): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True, (1, -1, 6): True, (-1, 0, 6): True, (0, 0, 6): True, (1, -1, 1): True, (-1, 3, 1): True, (0, 1, 1): True, (1, -1, 9): True, (-1, 4, 9): True, (0, 1, 9): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True, (1, -1, 6): True, (-1, 0, 6): True, (0, 0, 6): True, (1, -1, 1): True, (-1, 3, 1): True, (0, 1, 1): True, (1, -1, 9): True, (-1, 4, 9): True, (0, 1, 9): True, (1, -1, 5): True, (-1, 5, 5): True, (0, 1, 5): True}
# ---
# {(0, -1, 8): True, (-1, 0, 8): True, (0, 0, 8): True, (0, -1, 3): True, (-1, 1, 3): True, (0, 0, 3): True, (0, -1, 7): True, (-1, 4, 7): True, (0, 1, 7): True, (1, -1, 6): True, (-1, 0, 6): True, (0, 0, 6): True, (1, -1, 1): True, (-1, 3, 1): True, (0, 1, 1): True, (1, -1, 9): True, (-1, 4, 9): True, (0, 1, 9): True, (1, -1, 5): True, (-1, 5, 5): True, (0, 1, 5): True, (2, -1, 9): True, (-1, 1, 9): True, (0, 0, 9): True}
# ---
# False
